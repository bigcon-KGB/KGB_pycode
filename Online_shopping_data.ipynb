# %% [markdown]
# # 온라인 쇼핑 동향 확인
# - 상품군별_판매매체별(인터넷쇼핑/모바일쇼핑) 거래액 2019.02-2019.05 data 와 2020.02-2020.05 data 를 분석하기

# %% [markdown]
# ## import 및 설정 하기

# %%
import datetime
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
from numpy.polynomial.polynomial import polyfit
import matplotlib.style as style 
from IPython.display import Image
warnings.filterwarnings('ignore')
import matplotlib.font_manager as fm

# %%
sns.set_style("whitegrid")

font_location = "C:\Windows\Fonts/NanumGothic.ttf"
font_name = fm.FontProperties(fname=font_location).get_name()
mpl.rc("font", family=font_name)
mpl.rcParams["font.family"]
mpl.matplotlib_fname()
# Out:
# 'C:\\Users\\Jisoo\\anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %% [markdown]
# ## 1. 2019.02-2019.05 data read

# %%
online_2019_data = pd.read_csv("온라인쇼핑몰_판매매체별_상품군별거래액_2019.02_2019.07.csv", encoding = 'ANSI')

# %%
online_2019_data
# Out:
#           상품군별  판매매체별  2019. 02  2019. 03  2019. 04  2019. 05  2019. 06  \
# 0           합계      계   9607307  11259178  10671636  11253413  10604209
# 1           합계  인터넷쇼핑   3397801   4154481   3945263   4067849   3709250
# 2           합계  모바일쇼핑   6209506   7104697   6726373   7185564   6894959
# 3   컴퓨터 및 주변기기      계    540004    530200    466943    437182    386397
# 4   컴퓨터 및 주변기기  인터넷쇼핑    303189    311334    277452    261773    238393
# ..         ...    ...       ...       ...       ...       ...       ...
# 67       기타서비스  인터넷쇼핑     27781     27173     27623     32650     31068
# 68       기타서비스  모바일쇼핑     31458     36403     34762     43088     42031
# 69          기타      계    267559    386739    250508    251465    208820
# 70          기타  인터넷쇼핑    132183    228817    126663    120807     92063
# 71          기타  모바일쇼핑    135376    157922    123845    130658    116756
#
#     2019. 07  2020 2/4 p)
# 0   11197264     37492594
# 1    3951331     12272486
# 2    7245933     25220108
# 3     440060      1770708
# 4     268417      1036131
# ..       ...          ...
# 67     32809       120686
# 68     51394       178003
# 69    231253      1073252
# 70     99074       446067
# 71    132179       627187
#
# [72 rows x 9 columns]

# %% [markdown]
# ## 2. 2020.02-2020.05 data read

# %%
online_2020_data = pd.read_csv("온라인쇼핑몰_판매매체별_상품군별거래액_2020.02_2020.07.csv", encoding = 'ANSI')

# %%
online_2020_data
# Out:
#           상품군별  판매매체별  2020. 02  2020. 03  2020. 04  2020. 05  2020. 06 p)  \
# 0           합계      계  11963252  12624728  12065537  12742648     12684409
# 1           합계  인터넷쇼핑   3850850   4138678   4023773   4056283      4192430
# 2           합계  모바일쇼핑   8112402   8486051   8041765   8686365      8491978
# 3   컴퓨터 및 주변기기      계    616468    687759    645276    590327       535105
# 4   컴퓨터 및 주변기기  인터넷쇼핑    341426    387538    364862    349022       322247
# ..         ...    ...       ...       ...       ...       ...          ...
# 67       기타서비스  인터넷쇼핑     59394     27840     45916     35082        39688
# 68       기타서비스  모바일쇼핑     86230     36702     68617     54803        54583
# 69          기타      계    380936    387031    318471    389398       365383
# 70          기타  인터넷쇼핑    162845    185529    136878    162870       146319
# 71          기타  모바일쇼핑    218091    201502    181594    226529       219064
#
#     2020. 07 p)
# 0      12962537
# 1       4179253
# 2       8783284
# 3        608869
# 4        367476
# ..          ...
# 67        38085
# 68        61225
# 69       389308
# 70       149514
# 71       239794
#
# [72 rows x 8 columns]

# %% [markdown]
# ## 3. 식료품 전체 2019년 2020년 쇼핑 거래액 비교
# - 위의 23개의 상품군별 중 (합계 제외) 의식주 중에서 배달관련 소비패턴의 변화를 확인하기 위해 식료품 상품군별만 뽑아 비교하기.
# - 식료품 상품군 : 음식료품 / 농축수산물 / 음식 서비스
# - online 식료품 별 2019 / 2020 data 하나로 concat 하기.

# %%
# 2019년 식료품 상품군만 뽑기
online_data = online_2019_data[online_2019_data["상품군별"].isin(["합계", "음·식료품", "농축수산물", "음식서비스"])]

# %%
# 2020년 식료품 상품군만 뽑기
online_2020_food = online_2020_data[online_2020_data["상품군별"].isin(["합계", "음·식료품", "농축수산물", "음식서비스"])]
online_2020_food.drop(columns=["상품군별", "판매매체별"], inplace = True)

# %%
online = pd.concat([online_data, online_2020_food], axis=1)

# %%
# 2019년의 2020 2/4 p 컬럼은 필요 없으니 삭제하기
online.drop(columns="2020 2/4 p)", inplace =True)
online = online.reset_index(drop=True)

# %%
# 2019.02-2019.05 와 2020.02-2020.05 총계 구하기
online["2019_0205_총계"] = online.iloc[:, 2:6].sum(axis=1)
online["2020_0205_총계"] = online.iloc[:, 8:12].sum(axis=1)

# %%
# online_total.csv 저장 [2019, 2020 년 온라인 식료품 data]
online.to_csv("2019_2020_online_total.csv", index=False)

# %% [markdown]
# ### 1) 2019년 2020년 식료품 전체 온라인 쇼핑 거래액_증감액 및 증감률 시각화

# %%
# 2019년 2020년 증감액 및 증감률 시각화를 위한 column 생성
online["증감액(백만원)"] = online["2020_0205_총계"] - online["2019_0205_총계"]
online["증감률(%)"] = online["증감액(백만원)"]/online["2019_0205_총계"]*100

# %%
online
# Out:
#      상품군별  판매매체별  2019. 02  2019. 03  2019. 04  2019. 05  2019. 06  2019. 07  \
# 0      합계      계   9607307  11259178  10671636  11253413  10604209  11197264
# 1      합계  인터넷쇼핑   3397801   4154481   3945263   4067849   3709250   3951331
# 2      합계  모바일쇼핑   6209506   7104697   6726373   7185564   6894959   7245933
# 3   음·식료품      계    867779   1026995   1059837   1108562   1041017   1089666
# 4   음·식료품  인터넷쇼핑    276044    331854    351462    366378    339741    359413
# 5   음·식료품  모바일쇼핑    591735    695141    708375    742184    701275    730254
# 6   농축수산물      계    221292    265904    271458    269992    256778    267508
# 7   농축수산물  인터넷쇼핑     63695     81773     86283     83828     74977     78163
# 8   농축수산물  모바일쇼핑    157598    184131    185175    186165    181801    189344
# 9   음식서비스      계    616842    712110    687613    743966    775346    828720
# 10  음식서비스  인터넷쇼핑     46598     68185     46866     47660     49143     51793
# 11  음식서비스  모바일쇼핑    570244    643925    640747    696306    726203    776927
#
#     2020. 02  2020. 03  2020. 04  2020. 05  2020. 06 p)  2020. 07 p)  \
# 0   11963252  12624728  12065537  12742648     12684409     12962537
# 1    3850850   4138678   4023773   4056283      4192430      4179253
# 2    8112402   8486051   8041765   8686365      8491978      8783284
# 3    1481513   1631491   1520093   1477572      1450197      1598679
# 4     411253    442142    422759    395190       410042       444190
# 5    1070260   1189348   1097334   1082382      1040155      1154489
# 6     448870    517150    468172    416900       414963       462137
# 7     136818    137870    142339    111239       126962       150199
# 8     312052    379280    325833    305661       288001       311939
# 9    1135018   1251923   1263018   1320396      1252411      1378014
# 10     63931     66117     72737     83178        63758        68431
# 11   1071088   1185806   1190281   1237218      1188653      1309583
#
#     2019_0205_총계  2020_0205_총계  증감액(백만원)     증감률(%)
# 0       42791534      49396165   6604631  15.434434
# 1       15565394      16069584    504190   3.239173
# 2       27226140      33326583   6100443  22.406566
# 3        4063173       6110669   2047496  50.391554
# 4        1325738       1671344    345606  26.068952
# 5        2737435       4439324   1701889  62.170937
# 6        1028646       1851092    822446  79.954231
# 7         315579        528266    212687  67.395803
# 8         713069       1322826    609757  85.511641
# 9        2760531       4970355   2209824  80.050686
# 10        209309        285963     76654  36.622410
# 11       2551222       4684393   2133171  83.613696

# %% [markdown]
# ##### 2019년 2020년 증감액 시각화

# %%
index = online.iloc[:, 14:16].columns
plt.figure(figsize=(8,8))

plt.bar(index, online.iloc[0, 14:16], width = 0.5, align="center", color='#edecdf')
plt.xticks(index, ["2019", "2020"], fontsize=15)
plt.title("2019년_2020년 온라인 식료품 거래액", fontsize=25)
plt.xlabel("연도", fontsize=18)
plt.ylabel("총 거래액[백만원]", fontsize=18)
plt.grid(False)
plt.tight_layout()
plt.ylim(0,58000000)

for x, y in enumerate(online.iloc[0, 14:16]):
    plt.text(x, y, y,fontsize=20, color='dimgray', horizontalalignment='center', verticalalignment='bottom')

plt.savefig("2019_2020년 온라인 식료품 거래액.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# - 온라인 식료품 분야 2020년 거래액이 2019년보다 6604631 백 만원 증가 하였으며 15.43% 증가했습니다.

# %% [markdown]
# ### 2) 2019년 2020년 식료품별(음식료품, 농축산물, 음식서비스) 온라인 쇼핑 거래액_증감액 시각화

# %%
online_data = pd.read_csv("2019_2020_online_total.csv")

# %%
# 2019.02-2019.05 와 2020.02-2020.05 만 남기기
online_food_data = online_data.drop(columns = ["2019. 06", "2019. 07", "2020. 06 p)", "2020. 07 p)", "2019_0205_총계", "2020_0205_총계"])

# %%
online_food_data
# Out:
#      상품군별  판매매체별  2019. 02  2019. 03  2019. 04  2019. 05  2020. 02  2020. 03  \
# 0      합계      계   9607307  11259178  10671636  11253413  11963252  12624728
# 1      합계  인터넷쇼핑   3397801   4154481   3945263   4067849   3850850   4138678
# 2      합계  모바일쇼핑   6209506   7104697   6726373   7185564   8112402   8486051
# 3   음·식료품      계    867779   1026995   1059837   1108562   1481513   1631491
# 4   음·식료품  인터넷쇼핑    276044    331854    351462    366378    411253    442142
# 5   음·식료품  모바일쇼핑    591735    695141    708375    742184   1070260   1189348
# 6   농축수산물      계    221292    265904    271458    269992    448870    517150
# 7   농축수산물  인터넷쇼핑     63695     81773     86283     83828    136818    137870
# 8   농축수산물  모바일쇼핑    157598    184131    185175    186165    312052    379280
# 9   음식서비스      계    616842    712110    687613    743966   1135018   1251923
# 10  음식서비스  인터넷쇼핑     46598     68185     46866     47660     63931     66117
# 11  음식서비스  모바일쇼핑    570244    643925    640747    696306   1071088   1185806
#
#     2020. 04  2020. 05
# 0   12065537  12742648
# 1    4023773   4056283
# 2    8041765   8686365
# 3    1520093   1477572
# 4     422759    395190
# 5    1097334   1082382
# 6     468172    416900
# 7     142339    111239
# 8     325833    305661
# 9    1263018   1320396
# 10     72737     83178
# 11   1190281   1237218

# %%
# 식료품 상품군별 연도_월별 총계 값만 남는 dataframe 만들기
online_food = pd.DataFrame({"음·식료품_2019":online_food_data[online_food_data["상품군별"]=="음·식료품"].iloc[0,2:6].values, 
                            "음·식료품_2020":online_food_data[online_food_data["상품군별"]=="음·식료품"].iloc[0,6:].values,
                            "농축수산물_2019":online_food_data[online_food_data["상품군별"]=="농축수산물"].iloc[0,2:6].values, 
                            "농축수산물_2020":online_food_data[online_food_data["상품군별"]=="농축수산물"].iloc[0,6:].values,
                            "음식서비스_2019":online_food_data[online_food_data["상품군별"]=="음식서비스"].iloc[0,2:6].values, 
                            "음식서비스_2020":online_food_data[online_food_data["상품군별"]=="음식서비스"].iloc[0,6:].values,
                            "연도":["2월", "3월", "4월", "5월"]})

# %%
online_food.set_index("연도", inplace=True)

# %%
online_food
# Out:
#    음·식료품_2019 음·식료품_2020 농축수산물_2019 농축수산물_2020 음식서비스_2019 음식서비스_2020
# 연도
# 2월     867779    1481513     221292     448870     616842    1135018
# 3월    1026995    1631491     265904     517150     712110    1251923
# 4월    1059837    1520093     271458     468172     687613    1263018
# 5월    1108562    1477572     269992     416900     743966    1320396

# %% [markdown]
# ##### 식료품별 _연도별_월별 온라인 쇼핑거래 액 분석 시각화 함수

# %%
def plt_online_food(num1, num2, name):
    index = np.arange(4)
    alpha=0.5
    plt.figure(figsize=(18,9))
    bar_width=0.35
    ls = ["2월", "3월", "4월", "5월"]
    
    plt.bar(index, online_food.iloc[:, num1], bar_width, align="center", color='#95b391')
    plt.bar(index+bar_width, online_food.iloc[:, num2], bar_width, alpha=alpha, align="center", color='#393737')
    
    plt.title("{} 온라인 거래액".format(name), fontsize=25)
    plt.xlabel("월", fontsize=18)
    plt.ylabel("거래액[백만원]", fontsize=18)
    plt.xticks(index+0.14, ls, fontsize=18)
    plt.grid(False)
    plt.legend(online_food.columns[num1:num2+1], loc="upper left")
    plt.savefig("{} 온라인 거래액 연도별 비교.png".format(name), bbox_inches="tight")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##### 음·식료품 연도별_월별 온라인 쇼핑거래 액 분석 시각화

# %%
plt_online_food(0,1,"음·식료품")

# %% [markdown]
# ##### 농축수산물 연도별_월별 온라인 쇼핑거래 액 분석 시각화

# %%
plt_online_food(2, 3, "농축수산물")

# %% [markdown]
# ##### 음식서비스 연도별_월별 온라인 쇼핑거래 액 분석 시각화

# %%
plt_online_food(4, 5, "음식서비스")

# %% [markdown]
# - 음·식료품, 농축수산물, 음식서비스(배달) 모두 작년 동월대비 거래액이 증가했습니다.

# %% [markdown]
# ### 3) 2019년 2020년 식료품별(음식료품, 농축산물, 음식서비스) 온라인 쇼핑 거래액_증감률 시각화
# - 식료품별 전년대비 월별 증감률 변화 시각화

# %%
# 증감액 / 증감률 data 추가
online_food["음·식료품_증감액"] = online_food["음·식료품_2020"]-online_food["음·식료품_2019"]
online_food["농축수산물_증감액"] = online_food["농축수산물_2020"]-online_food["농축수산물_2019"]
online_food["음식서비스_증감액"] = online_food["음식서비스_2020"]-online_food["음식서비스_2019"]
online_food["음·식료품_증감률(%)"] = online_food["음·식료품_증감액"]/online_food["음·식료품_2019"]*100
online_food["농축수산물_증감률(%)"] = online_food["농축수산물_증감액"]/online_food["농축수산물_2019"]*100
online_food["음식서비스_증감률(%)"] = online_food["음식서비스_증감액"]/online_food["음식서비스_2019"]*100

# %%
online_food
# Out:
#    음·식료품_2019 음·식료품_2020 농축수산물_2019 농축수산물_2020 음식서비스_2019 음식서비스_2020  \
# 연도
# 2월     867779    1481513     221292     448870     616842    1135018
# 3월    1026995    1631491     265904     517150     712110    1251923
# 4월    1059837    1520093     271458     468172     687613    1263018
# 5월    1108562    1477572     269992     416900     743966    1320396
#
#    음·식료품_증감액 농축수산물_증감액 음식서비스_증감액 음·식료품_증감률(%) 농축수산물_증감률(%) 음식서비스_증감률(%)
# 연도
# 2월    613734    227578    518176      70.7247      102.841      84.0047
# 3월    604496    251246    539813      58.8607      94.4875      75.8047
# 4월    460256    196714    575405      43.4271      72.4657      83.6815
# 5월    369010    146908    576430      33.2873       54.412      77.4807

# %% [markdown]
# ##### 전년 대비 증감률 월별 변화량 시각화

# %%
plt.figure(figsize=(18,9))

plt.plot(online_food.index, online_food["음·식료품_증감률(%)"], color="#8da78c", linestyle="--", marker="8", 
         linewidth=7.0, markersize=12, label="음·식료품_증감률(%)", alpha=0.8)
plt.plot(online_food.index, online_food["농축수산물_증감률(%)"], color="#393737",linewidth=7.0, linestyle="--", marker="8",
         markersize=12, label="농축수산물_증감률(%)", alpha=0.7)
plt.plot(online_food.index, online_food["음식서비스_증감률(%)"], color="#8F0853", linewidth=7.0, linestyle="--", marker="8",
         markersize=12, label="음식서비스_증감률(%)", alpha=0.7)

plt.xticks(online_food.index, fontsize=18)
plt.title("식료품별 전년 대비 증감률(%)", fontsize=25)
plt.xlabel("월", fontsize=18)
plt.ylabel("전년 대비 증감률(%)", fontsize=18)
plt.legend(loc="upper right", fontsize=18)
plt.savefig("식료품별 전년 대비 증감량(%).png", boox_inches='tight')

plt.show()

# %% [markdown]
# - 코로나의 여파로 작년 대비 동월 기간 최소 33% 최대 102% 증가한 모습을 보이고 있습니다.
# - 음·식료품와 농축수산물의 증가률은 시간이 지나면서 감소하고 있지만 음식서비스(배달)은 큰 변화 없이 75%~85% 정도의 전년동월비 증가률을 보여 주고 있습니다.
